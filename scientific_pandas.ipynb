# %% [markdown]
# SCT211-0504/2021
#
# Gatmach Yuol Nyuon
#
# ICS2207: Scientific Computing
#
# Assignment No.4

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a series
s= pd.Series([1, 2, 3, 4, 5, None, 6, 8])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# 6    6.0
# 7    8.0
# dtype: float64

# %%
# create a DataFrame
data = {'name': ['John', 'Anna', 'Peter', 'Linda'], 'location': ['New York', 'Paris', 'Berlin', 'London'], 'age': [24,13,53, 33]}

# %%
data
# Out:
# {'name': ['John', 'Anna', 'Peter', 'Linda'],
#  'location': ['New York', 'Paris', 'Berlin', 'London'],
#  'age': [24, 13, 53, 33]}

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)
df
# Out:
#     name  location  age
# 0   John  New York   24
# 1   Anna     Paris   13
# 2  Peter    Berlin   53
# 3  Linda    London   33

# %%
'''Pandas read CSV files that containing data for the business operations
  Store data for business-operations-survey-2022-price-and-wage-setting
'''
df_csv = pd.read_csv('./business_data.csv',encoding='latin-1', header =None)
df_csv
# Out:
#                                                        0  \
# 0                                            description
# 1      Business main customer: individuals or households
# 2      Business main customer: individuals or households
# 3      Business main customer: individuals or households
# 4      Business main customer: individuals or households
# ...                                                  ...
# 14754  How union representation of employees has affe...
# 14755  How union representation of employees has affe...
# 14756  How union representation of employees has affe...
# 14757  How union representation of employees has affe...
# 14758  How union representation of employees has affe...
#
#                                      1      2                3          4  \
# 0                             industry  level             size  line_code
# 1                                total      0   619 employees   C0300.01
# ...

# %%
df_csv.head(10)
# Out:
#                                                    0  \
# 0                                        description
# 1  Business main customer: individuals or households
# 2  Business main customer: individuals or households
# 3  Business main customer: individuals or households
# 4  Business main customer: individuals or households
# 5  Business main customer: individuals or households
# 6  Business main customer: individuals or households
# 7  Business main customer: individuals or households
# 8  Business main customer: individuals or households
# 9  Business main customer: individuals or households
#
#                                                    1      2                3  \
# 0                                           industry  level             size
# 1                                              total      0   619 employees
# 2                                              total      0  2049 employees
# ...

# %%
# plots csv dataset for business_data
df_csv = pd.read_csv('./business_data.csv',encoding='latin-1' )
df_csv.plot()
plt.show()

# %%
# plot scatter for the csv file dataset with headers

df_csv.plot(kind='scatter', x='line_code', y='value')
plt.show()

# %%
df_csv.plot(kind='line', x='line_code', y='value', title='Business operations: line_code against value ')
# plt.title('line_code against value')
plt.show()

# %%
df_csv['value'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_excelxlsx = pd.read_excel('./data_example.xlsx')

# %%
'''Pandas read Excel
'''
df_excelxlsx = pd.read_excel('./data_example.xlsx', header=None)
df_excelxlsx
# Out:
#        0        1      2                                 3  \
# 0   2021  Level 3   RS11      Arts and Recreation Services
# 1   2021  Level 3   RS11      Arts and Recreation Services
# 2   2021  Level 3   RS11      Arts and Recreation Services
# 3   2021  Level 4  RS111  Heritage and Artistic Activities
# 4   2021  Level 4  RS111  Heritage and Artistic Activities
# 5   2021  Level 4  RS111  Heritage and Artistic Activities
# 6   2021  Level 4  RS111  Heritage and Artistic Activities
# 7   2021  Level 4  RS111  Heritage and Artistic Activities
# 8   2021  Level 4  RS111  Heritage and Artistic Activities
# 9   2021  Level 4  RS111  Heritage and Artistic Activities
# 10  2021  Level 4  RS111  Heritage and Artistic Activities
# 11  2021  Level 4  RS111  Heritage and Artistic Activities
# 12  2021  Level 4  RS111  Heritage and Artistic Activities
# 13  2021  Level 4  RS111  Heritage and Artistic Activities
# 14  2021  Level 4  RS111  Heritage and Artistic Activities
# ...

# %%
df_excelxlsx.tail(7)
# Out:
#        0        1      2                                 3  \
# 22  2021  Level 4  RS111  Heritage and Artistic Activities
# 23  2021  Level 4  RS111  Heritage and Artistic Activities
# 24  2021  Level 4  RS111  Heritage and Artistic Activities
# 25  2021  Level 4  RS111  Heritage and Artistic Activities
# 26  2021  Level 4  RS111  Heritage and Artistic Activities
# 27  2021  Level 4  RS111  Heritage and Artistic Activities
# 28  2021  Level 4  RS111  Heritage and Artistic Activities
#
#                      4    5                                    6  \
# 22  Dollars (millions)  H28            Disposals of fixed assets
# 23  Dollars (millions)  H29                         Other assets
# 24  Dollars (millions)  H30         Total equity and liabilities
# 25  Dollars (millions)  H31  Shareholders funds or owners equity
# 26  Dollars (millions)  H32                  Current liabilities
# 27  Dollars (millions)  H33                    Other liabilities
# ...

# %%
df_excelxlsx.sample(10)
# Out:
#        0        1      2                                 3  \
# 24  2021  Level 4  RS111  Heritage and Artistic Activities
# 19  2021  Level 4  RS111  Heritage and Artistic Activities
# 27  2021  Level 4  RS111  Heritage and Artistic Activities
# 15  2021  Level 4  RS111  Heritage and Artistic Activities
# 11  2021  Level 4  RS111  Heritage and Artistic Activities
# 21  2021  Level 4  RS111  Heritage and Artistic Activities
# 22  2021  Level 4  RS111  Heritage and Artistic Activities
# 23  2021  Level 4  RS111  Heritage and Artistic Activities
# 9   2021  Level 4  RS111  Heritage and Artistic Activities
# 2   2021  Level 3   RS11      Arts and Recreation Services
#
#                      4    5                             6  \
# 24  Dollars (millions)  H30  Total equity and liabilities
# 19  Dollars (millions)  H25                Current assets
# 27  Dollars (millions)  H33             Other liabilities
# 15  Dollars (millions)  H21                Opening stocks
# ...

# %%
df_excelxlsx.head(6)
# Out:
#       0        1      2                                 3                   4  \
# 0  2021  Level 3   RS11      Arts and Recreation Services          Percentage
# 1  2021  Level 3   RS11      Arts and Recreation Services          Percentage
# 2  2021  Level 3   RS11      Arts and Recreation Services          Percentage
# 3  2021  Level 4  RS111  Heritage and Artistic Activities  Dollars (millions)
# 4  2021  Level 4  RS111  Heritage and Artistic Activities  Dollars (millions)
# 5  2021  Level 4  RS111  Heritage and Artistic Activities  Dollars (millions)
#
#      5                                                6  \
# 0  H39                                 Return on equity
# 1  H40                           Return on total assets
# 2  H41                            Liabilities structure
# 3  H01                                     Total income
# 4  H04  Sales, government funding, grants and subsidies
# 5  H05                Interest, dividends and donations
#
# ...

# %%
df_excel = pd.read_excel('./data_example.xlsx')
df_excel.head()
# Out:
#    2021  Level 3   RS11      Arts and Recreation Services          Percentage  \
# 0  2021  Level 3   RS11      Arts and Recreation Services          Percentage
# 1  2021  Level 3   RS11      Arts and Recreation Services          Percentage
# 2  2021  Level 4  RS111  Heritage and Artistic Activities  Dollars (millions)
# 3  2021  Level 4  RS111  Heritage and Artistic Activities  Dollars (millions)
# 4  2021  Level 4  RS111  Heritage and Artistic Activities  Dollars (millions)
#
#    H39                                 Return on equity  \
# 0  H40                           Return on total assets
# 1  H41                            Liabilities structure
# 2  H01                                     Total income
# 3  H04  Sales, government funding, grants and subsidies
# 4  H05                Interest, dividends and donations
#
#         Financial ratios   14                   ANZSIC06 division R
# 0       Financial ratios   10                   ANZSIC06 division R
# ...

# %%
# plot scatter for the Excel file dataset with headers
# df_csv.plot()

df_excel.plot(kind='scatter', x='Arts and Recreation Services', y='Financial ratios')

plt.show()

# %%
# End Of The File
